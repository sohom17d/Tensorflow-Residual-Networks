# %%
from models.resnet_50 import *
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
# Out:
# Using TensorFlow backend.

# %%
resnet = Resnet50((64, 64, 3), 6)
resnet.model.summary()
# Out:
# WARNING:tensorflow:From /home/soumikr/Workspace/residual_networks/env/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 70, 70, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 32, 32, 64)   9472        zero_padding2d[0][0]
# ...

# %%
SVG(model_to_dot(resnet.model, show_shapes = True, show_layer_names = True).create(prog = 'dot', format = 'svg'))
